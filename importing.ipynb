# %%
import pandas as pd
df=pd.read_csv('test.txt',header=10,sep='   ', warn_bad_lines=False)
df.head()
# Out:
# C:\Users\plasm\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#     dd-mm-yyyy hh:mm:ss.ms  Unnamed: 1  Unnamed: 2  Unnamed: 3    nT  \
# 0  01-01-2019 00:00:00.000         NaN       -3.82         NaN  1.54
# 1  01-01-2019 00:01:00.000         NaN       -3.37         NaN  2.12
# 2  01-01-2019 00:02:00.000         NaN       -3.36         NaN  2.49
# 3  01-01-2019 00:03:00.000         NaN       -3.53         NaN  2.20
# 4  01-01-2019 00:04:00.000         NaN       -3.48         NaN  2.46
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  nT  Unnamed: 9  ...  Unnamed: 18  \
# 0         NaN        2.92         NaN NaN     99999.9  ...          NaN
# 1         NaN        2.63         NaN NaN      -451.1  ...          NaN
# ...

# %%
df.columns
# Out:
# Index(['dd-mm-yyyy hh:mm:ss.ms', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        ' nT', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'nT', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'nT.1', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', ' km/s', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        ' km/s.1', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', ' km/s.2',
#        'Unnamed: 25', 'Unnamed: 26', '  n/cc'],
#       dtype='object')

# %%
df=df[['dd-mm-yyyy hh:mm:ss.ms', 'Unnamed: 1', 'Unnamed: 2', ' nT',
       'Unnamed: 5',  'Unnamed: 7', 'nT.1',
       'Unnamed: 11']]

# %%
df.head()
# Out:
#     dd-mm-yyyy hh:mm:ss.ms  Unnamed: 1  Unnamed: 2    nT  Unnamed: 5  \
# 0  01-01-2019 00:00:00.000         NaN       -3.82  1.54         NaN
# 1  01-01-2019 00:01:00.000         NaN       -3.37  2.12         NaN
# 2  01-01-2019 00:02:00.000         NaN       -3.36  2.49         NaN
# 3  01-01-2019 00:03:00.000         NaN       -3.53  2.20         NaN
# 4  01-01-2019 00:04:00.000         NaN       -3.48  2.46         NaN
#
#    Unnamed: 7     nT.1  Unnamed: 11
# 0         NaN  99999.9          NaN
# 1         NaN     10.1          NaN
# 2         NaN     10.1          NaN
# 3         NaN  99999.9          NaN
# 4         NaN     10.0          NaN

# %%
name=['EPOCH_TIME','BX','BY','BZ','VX',
      'VY' ,'VZ' ,'PROTON_DENSITY']

# %%
df.columns=name
df.head()
# Out:
#                 EPOCH_TIME  BX    BY    BZ  VX  VY       VZ  PROTON_DENSITY
# 0  01-01-2019 00:00:00.000 NaN -3.82  1.54 NaN NaN  99999.9             NaN
# 1  01-01-2019 00:01:00.000 NaN -3.37  2.12 NaN NaN     10.1             NaN
# 2  01-01-2019 00:02:00.000 NaN -3.36  2.49 NaN NaN     10.1             NaN
# 3  01-01-2019 00:03:00.000 NaN -3.53  2.20 NaN NaN  99999.9             NaN
# 4  01-01-2019 00:04:00.000 NaN -3.48  2.46 NaN NaN     10.0             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83524 entries, 0 to 83523
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EPOCH_TIME      83524 non-null  object
#  1   BX              7962 non-null   float64
#  2   BY              76100 non-null  float64
#  3   BZ              71081 non-null  float64
#  4   VX              25022 non-null  float64
#  5   VY              3517 non-null   float64
#  6   VZ              54200 non-null  float64
#  7   PROTON_DENSITY  25330 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 5.1+ MB

# %%
df.describe()
# Out:
#                 BX            BY            BZ            VX            VY  \
# count  7962.000000  76100.000000  71081.000000  25022.000000   3517.000000
# mean     -0.415603   1136.920033   1215.344400     -0.339855  18790.193005
# std       0.308752   3172.531370   3268.400229      1.878417  39474.242574
# min      -0.990000     -9.110000    -14.390000    -18.570000   -658.000000
# 25%      -0.670000      0.290000     -2.550000     -0.950000   -414.000000
# 50%      -0.400000      2.200000     -0.050000     -0.420000   -353.900000
# 75%      -0.150000      3.890000      2.650000      0.220000   -305.600000
# max       0.090000   9999.990000   9999.990000     11.080000  99999.900000
#
#                  VZ  PROTON_DENSITY
# count  54200.000000    25330.000000
# mean   32738.271293    19963.710071
# std    46925.907014    39974.448308
# min      -70.200000      -65.800000
# 25%       -7.100000       -7.800000
# 50%        9.800000        1.600000
# ...

# %%
import numpy as np
df['BY']=df['BY'].apply(lambda x: 5 if x>=9000 else x)
df['BZ']=df['BZ'].apply(lambda x: 5 if x>=9000 else x)
df['VY']=df['VY'].apply(lambda x: 5 if x>=9000 else x)
df['VZ']=df['VZ'].apply(lambda x: 5 if x>=9000 else x)
df['PROTON_DENSITY']=df['PROTON_DENSITY'].apply(lambda x: 5 if x>=9000 else x)

# %%
df.describe()
# Out:
#                 BX            BY            BZ            VX           VY  \
# count  7962.000000  76100.000000  71081.000000  25022.000000  3517.000000
# mean     -0.415603      1.746595      0.016836     -0.339855  -316.026159
# std       0.308752      2.873964      3.414838      1.878417   169.488021
# min      -0.990000     -9.110000    -14.390000    -18.570000  -658.000000
# 25%      -0.670000      0.290000     -2.550000     -0.950000  -414.000000
# 50%      -0.400000      2.200000     -0.050000     -0.420000  -353.900000
# 75%      -0.150000      3.890000      2.650000      0.220000  -305.600000
# max       0.090000     16.180000     12.240000     11.080000     5.000000
#
#                  VZ  PROTON_DENSITY
# count  54200.000000    25330.000000
# mean       1.933552        0.259250
# std       18.502395       15.769498
# min      -70.200000      -65.800000
# 25%       -7.100000       -7.800000
# 50%        5.000000        1.600000
# 75%        5.000000        5.000000
# ...

# %%
import seaborn as sns
sns.set()

# %%
df=df.drop(['BX','VY'],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83524 entries, 0 to 83523
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EPOCH_TIME      83524 non-null  object
#  1   BY              76100 non-null  float64
#  2   BZ              71081 non-null  float64
#  3   VX              25022 non-null  float64
#  4   VZ              54200 non-null  float64
#  5   PROTON_DENSITY  25330 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 3.8+ MB

# %%
df=df.dropna(subset=['VX'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25022 entries, 28 to 83518
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EPOCH_TIME      25022 non-null  object
#  1   BY              19017 non-null  float64
#  2   BZ              12631 non-null  float64
#  3   VX              25022 non-null  float64
#  4   VZ              10 non-null     float64
#  5   PROTON_DENSITY  24426 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 1.3+ MB

# %%
df=df.

# %%
sns.pairplot(df)
